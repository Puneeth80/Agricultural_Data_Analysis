# %%
import agri_project_main

# Point to your CSV file
# Note: In Jupyter, you might not need the ".." if the csv is in the same folder.
csv_path = "Downloads/Crops_EDA_Project/Agricultural Data Analysis (Python) /Data Files/crop_yield_data.csv" 

# Create the App Object
app = agri_project_main.AgriAnalyticsApp(csv_path)

# Run it
app.run()
# Out:
# === 🚜 AGRICULTURAL DATA ANALYSIS PROJECT START ===
# ❌ Critical Error: The file 'crop_yield_data.csv' is missing!
