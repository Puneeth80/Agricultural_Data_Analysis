# %%
import importlib
import agri_project_main

# %%
# Force Python to read the new code
importlib.reload(agri_project_main)

# Run
agri_project_main.main()
# Out:
# Locating dataset...
# Dataset found at: /Users/puneethreddy/Downloads/Crops_EDA_Project/Agricultural Data Analysis (Python) /Data Files/crop_yield_data.csv
# Starting Agricultural Data Analysis...
# Successfully loaded data from: /Users/puneethreddy/Downloads/Crops_EDA_Project/Agricultural Data Analysis (Python) /Data Files/crop_yield_data.csv
# Processing: Calculating Yield per Hectare (Efficiency Metric)...
#
# --- Statistical Summary ---
# Correlation (Rain vs Yield): 0.0863
# Correlation (Size vs Yield): 0.9892
#
# Generating visualizations...
# Saved visualization: Results/correlation_heatmap.png
#    🎯 Saved Key Insight graph to result folder
# Saved visualization: Results/rainfall_impact.png
#
# Analysis complete. Results saved in 'Results' folder.

# %%
import os
import subprocess
import glob

# --- CREDENTIALS ---
GITHUB_TOKEN = "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"
USERNAME = "Puneeth80"
REPO_NAME = "Agricultural_Data_Analysis"

# 1. Find the Project Folder
base_dir = os.path.expanduser("~/Downloads/Crops_EDA_Project")
print(f"🔎 Scanning: {base_dir}")

found_folders = glob.glob(os.path.join(base_dir, "Agricultural*"))

if found_folders:
    target_folder = found_folders[0]
    print(f"✅ Found Folder: {target_folder}")
    os.chdir(target_folder)

    # 2. Setup README if missing
    if not os.path.exists("README.md"):
        with open("README.md", "w") as f:
            f.write(f"# {REPO_NAME}\n\nAnalysis of global crop production and yield.")

    # 3. RUN COMMANDS (Force Push)
    remote_url = f"https://{USERNAME}:{GITHUB_TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git"
    
    commands = [
        "rm -rf .git",        # Delete old git settings (start fresh)
        "git init",           # Initialize new git
        "git add .",          # Add ALL files (including your notebook)
        'git commit -m "First Upload"', # Save locally
        "git branch -M main", # Name branch 'main'
        f"git remote add origin {remote_url}", # Connect to GitHub
        "git push -u --force origin main"      # FORCE upload
    ]

    print("\n🚀 Starting Upload...")
    for cmd in commands:
        try:
            # We run this way to capture errors
            result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
            if result.returncode != 0:
                print(f"⚠️ Warning: {result.stderr.strip()}")
            else:
                if "push" in cmd:
                    print("☁️  Pushing files to GitHub...")
        except Exception as e:
            print(f"❌ Execution Error: {e}")

    print("\n✅ DONE! Refresh your GitHub page now:")
    print(f"https://github.com/{USERNAME}/{REPO_NAME}")

else:
    print("❌ Error: Could not find the folder 'Agricultural Data Analysis (Python)'.")
# Out:
# 🔎 Scanning: /Users/puneethreddy/Downloads/Crops_EDA_Project
# ✅ Found Folder: /Users/puneethreddy/Downloads/Crops_EDA_Project/Agricultural Data Analysis (Python)
#
# 🚀 Starting Upload...
# ⚠️ Warning: remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/Puneeth80/Agricultural_Data_Analysis.git/'
#
# ✅ DONE! Refresh your GitHub page now:
# https://github.com/Puneeth80/Agricultural_Data_Analysis
